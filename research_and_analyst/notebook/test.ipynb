# %%
print("ok")
# Out:
# ok

# %%
import sys, os

# Get project root — one level up from 'research_and_analyst'
project_root = os.path.abspath(os.path.join(os.getcwd(), "../.."))
sys.path.append(project_root)

print("Project root added to path:", project_root)
# Out:
# Project root added to path: d:\DataScience\LLMOPS\AUTOMATED-RESEARCH-REPORT-GENERATION

# %%
from research_and_analyst.utils.model_loader import ModelLoader

# %%
model_loader = ModelLoader()
# Out:
# {"timestamp": "2025-10-25T10:58:41.388348Z", "level": "info", "event": "OPENAI_API_KEY loaded from environment"}
# {"timestamp": "2025-10-25T10:58:41.388348Z", "level": "info", "event": "GOOGLE_API_KEY loaded from environment"}
# {"timestamp": "2025-10-25T10:58:41.388348Z", "level": "info", "event": "GROQ_API_KEY loaded from environment"}
# {"timestamp": "2025-10-25T10:58:41.388348Z", "level": "warning", "event": "ASTRA_DB_API_ENDPOINT is missing from environment"}
# {"timestamp": "2025-10-25T10:58:41.394344Z", "level": "warning", "event": "ASTRA_DB_APPLICATION_TOKEN is missing from environment"}
# {"timestamp": "2025-10-25T10:58:41.394344Z", "level": "warning", "event": "ASTRA_DB_KEYSPACE is missing from environment"}
# {"config_keys": ["astra_db", "embedding_model", "retriever", "llm"], "timestamp": "2025-10-25T10:58:41.396910Z", "level": "info", "event": "YAML config loaded"}

# %%
llm=model_loader.load_llm()
# Out:
# {"provider": "google", "model": "gemini-2.0-flash", "timestamp": "2025-10-25T10:58:41.405406Z", "level": "info", "event": "Loading LLM"}

# %%
llm.invoke("hi").content
# Out:
# 'Hi there! How can I help you today?'
